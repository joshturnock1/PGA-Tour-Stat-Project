# %%
import pandas as pd

# %% [markdown]
# # Changing the Money variable to an integer

# %%
df = pd.read_csv("../Data Analytics Projects/PGA_Tour_cleaned.csv")
df
# Out:
#       Unnamed: 0     Player Name  Rounds  Fairway Percentage  Year  \
# 0              0  Henrik Stenson    60.0               75.19  2018
# 1              1     Ryan Armour   109.0               73.58  2018
# 2              2     Chez Reavie    93.0               72.24  2018
# 3              3      Ryan Moore    78.0               71.94  2018
# 4              4    Brian Stuard   103.0               71.44  2018
# ...          ...             ...     ...                 ...   ...
# 1669        1673  Phil Mickelson    76.0               52.66  2010
# 1670        1674       John Daly    63.0               52.21  2010
# 1671        1675    Jimmy Walker    82.0               51.29  2010
# 1672        1676   Daniel Chopra    74.0               51.27  2010
# 1673        1677   Martin Flores    75.0               50.15  2010
#
#       Avg Distance    gir  Average Putts  Average Scrambling  Average Score  \
# 0            291.5  73.51          29.93               60.67         69.617
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1674 entries, 0 to 1673
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1674 non-null   int64
#  1   Player Name         1674 non-null   object
#  2   Rounds              1674 non-null   float64
#  3   Fairway Percentage  1674 non-null   float64
#  4   Year                1674 non-null   int64
#  5   Avg Distance        1674 non-null   float64
#  6   gir                 1674 non-null   float64
#  7   Average Putts       1674 non-null   float64
#  8   Average Scrambling  1674 non-null   float64
#  9   Average Score       1674 non-null   float64
#  10  Wins                1674 non-null   float64
#  11  Top 10              1674 non-null   float64
#  12  Average SG Putts    1674 non-null   float64
#  13  Average SG Total    1674 non-null   float64
#  14  SG:OTT              1674 non-null   float64
# ...

# %%
df['Money'] = df['Money'].replace('[\$,]', '', regex=True).astype(int)

# %%
print(df['Money'].dtype)
print(df['Money'].head())
# Out:
# int64
# 0    2680487
# 1    2485203
# 2    2700018
# 3    1986608
# 4    1089763
# Name: Money, dtype: int64

# %%
df.to_csv("../Data Analytics Projects/PGA_Tour_cleaned1.csv")
